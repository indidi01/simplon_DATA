# %% [markdown]
# You must correct each of the scripts below **using exception handling** and **without modifying lists**.

# %% [markdown]
# Script number 1

# %%
list_integers = [1, 12, -45, 6, 27, 0, 24]
for i in list_integers:
  print(1/i)
# Out:
# 1.0
# 0.08333333333333333
# -0.022222222222222223
# 0.16666666666666666
# 0.037037037037037035
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-1-a3253ca8e904> in <cell line: 2>()
#       1 list_integers = [1, 12, -45, 6, 27, 0, 24]
#       2 for i in list_integers:
# ----> 3   print(1/i)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Script number 2

# %%
list_integers = [1, 12, -45, 6, 27, 24]
for i in range(10):
  print(1/list_integers[i])
# Out:
# 1.0
# 0.08333333333333333
# -0.022222222222222223
# 0.16666666666666666
# 0.037037037037037035
# 0.041666666666666664
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-a99bfde4bc75> in <cell line: 2>()
#       1 list_integers = [1, 12, -45, 6, 27, 24]
#       2 for i in range(10):
# ----> 3   print(1/list_integers[i])
#
# IndexError: list index out of range

# %% [markdown]
# Script number 3

# %%
list_integers = [1, 12, -45, 6, 27, 0, 24]
for i in range(10):
  print(1/list_integers[i])
# Out:
# 1.0
# 0.08333333333333333
# -0.022222222222222223
# 0.16666666666666666
# 0.037037037037037035
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-3-e6cab0862607> in <cell line: 2>()
#       1 list_integers = [1, 12, -45, 6, 27, 0, 24]
#       2 for i in range(10):
# ----> 3   print(1/list_integers[i])
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Script number 4

# %%
list_words = ['hello', 'good morning', 'GOOD Evening', 34, 'Bye' ]

for word in list_words:
  print(word.upper())
# Out:
# HELLO
# GOOD MORNING
# GOOD EVENING
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-be576052e4ab> in <cell line: 3>()
#       2
#       3 for word in list_words:
# ----> 4   print(word.upper())
#
# AttributeError: 'int' object has no attribute 'upper'
