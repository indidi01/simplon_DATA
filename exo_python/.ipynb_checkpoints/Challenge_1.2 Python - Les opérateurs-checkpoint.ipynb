# %% [markdown]
# # 1. Calcul d'un prix

# %% [markdown]
# Ecrivez un programme faisant saisir à l’utilisateur un prix unitaire HT, un taux de TVA et un nombre d’articles, et qui calcule le montant TTC de l’achat.<br>
# Affichez le montant TTC.

# %%
prix_unitaire = int(input())
taux_tva = int(input()) / 100 + 1
nombre_articles = int(input())
montant_ttc = prix_unitaire * taux_tva * nombre_articles

print(montant_ttc)
# Out:
#  5
#  10
#  5
# 27.5

# %% [markdown]
# # 2. Conversion de durées (1)

# %% [markdown]
# Ecrivez un programme demandant une durée en secondes à l’utilisateur, et qui la convertit en heures, minutes, secondes.<br>
# Affichez le résultat.<br>
# Par exemple 12334 deviendra 3 heures, 25 minutes et 34 secondes.

# %%
duree = int(input())
heures = duree//60//60
minutes = duree//60%60
secondes = duree%60

print(heures, "heures")
print(minutes, "minutes")
print(secondes, "secondes")
# Out:
#  12334
# 3 heures
# 25 minutes
# 34 secondes

# %% [markdown]
# # 3. Conversion de durées (2)

# %% [markdown]
# Ecrivez un programme demandant une durée en heures, minutes, secondes à l’utilisateur et qui la convertit en secondes.<br>
# Affichez le résultat.<br>
# Par exemple 3 heures, 25 minutes et 34 secondes deviendra 12334 secondes.

# %%
duree_heures = int(input())
duree_minutes = int(input())
duree_secondes = int(input())
secondes = duree_heures*60*60 + duree_minutes*60 + duree_secondes

print(duree_heures, "heures", duree_minutes, "minutes", duree_secondes, "secondes", "=", secondes, "secondes")
# Out:
#  3
#  25
#  34
# 3 heures 25 minutes 34 secondes = 12334 secondes
